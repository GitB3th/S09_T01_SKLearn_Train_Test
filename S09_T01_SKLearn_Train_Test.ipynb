# %% [markdown]
# # S09_T01_SKLearn_Train_Test
#
# ### Ex1: Parteix el conjunt de dades DelayedFlights.csv en train i test. Estudia els dos conjunts per separat, a nivell descriptiu

# %%
#Importem llibreries necessàries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from scipy import stats
from sklearn.model_selection import train_test_split

# %%
#carreguem dataset DelayedFlights.csv de la carpeta del Sprin2_Task5
pd.set_option("display.max_columns", None)
data_frame = pd.read_csv("C:/Users/Beth/Python_Projects/Tasks_Sprint2/Task5/DelayedFlights.csv")
data_frame.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0   2211.0        2225            WN        335  N712SW              128.0
# 1   1002.0        1000            WN       3231  N772SW              128.0
# 2    804.0         750            WN        448  N428WN               96.0
# 3   1959.0        1925            WN       3920  N464WN               90.0
# 4   2121.0        2110            WN        378  N726SW              101.0
#
#    CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  TaxiIn  \
# ...

# %%
data_frame.shape
# Out:
# (1936758, 30)

# %%
#Split dataframe en train_test
train, test = train_test_split(data_frame, test_size=0.33, random_state=4)

# %%
train.head()
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 84384        264774  2008      1           7          1   1603.0        1555
# 1424846     4830732  2008      8           6          3   1830.0        1735
# 1923886     6975990  2008     12          25          4   2019.0        2005
# 383942      1206280  2008      3          12          3   1653.0        1630
# 1811287     6665008  2008     12          13          6   1857.0        1752
#
#          ArrTime  CRSArrTime UniqueCarrier  FlightNum TailNum  \
# 84384     1823.0        1841            US        777  N921UW
# 1424846   2131.0        2026            DL        716  N950DL
# 1923886   2136.0        2138            CO        487  N76505
# 383942    1753.0        1735            WN         47  N359SW
# 1811287   2239.0        2127            UA        167  N513UA
#
#          ActualElapsedTime  CRSElapsedTime  AirTime  ArrDelay  DepDelay  \
# ...

# %%
test.head()
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 700956      2292478  2008      4          24          4   1204.0        1150
# 876909      2970491  2008      5          26          1   2147.0        2130
# 64689        211985  2008      1          28          1   1639.0        1556
# 563728      1760556  2008      3           8          6    332.0        2005
# 1728398     6440552  2008     11          11          2   2152.0        2055
#
#          ArrTime  CRSArrTime UniqueCarrier  FlightNum TailNum  \
# 700956    1328.0        1300            AA       1456  N590AA
# 876909      20.0          27            CO        354  N73283
# 64689     1844.0        1731            OO       3802  N449SW
# 563728     610.0        2253            CO       1449  N69311
# 1728398     31.0        2221            CO        442  N24633
#
#          ActualElapsedTime  CRSElapsedTime  AirTime  ArrDelay  DepDelay  \
# ...

# %%
#Podem comprovar com s'ha dividit en els 2 grups, mirant la shape de tots dos:
print("Dimensions train: ", train.shape)
print("Dimensions test: ", test.shape)
# Out:
# Dimensions train:  (1297627, 30)
# Dimensions test:  (639131, 30)

# %%
#Estudiem les diferències entre els dos conjunts:
train.describe().round(2)
# Out:
#        Unnamed: 0       Year       Month  DayofMonth   DayOfWeek     DepTime  \
# count  1297627.00  1297627.0  1297627.00  1297627.00  1297627.00  1297627.00
# mean   3340951.84     2008.0        6.11       15.75        3.98     1518.76
# std    2065510.93        0.0        3.48        8.78        2.00      450.48
# min          2.00     2008.0        1.00        1.00        1.00        1.00
# 25%    1516894.00     2008.0        3.00        8.00        2.00     1203.00
# 50%    3241356.00     2008.0        6.00       16.00        4.00     1545.00
# 75%    4971673.00     2008.0        9.00       23.00        6.00     1900.00
# max    7009727.00     2008.0       12.00       31.00        7.00     2400.00
#
#        CRSDepTime     ArrTime  CRSArrTime   FlightNum  ActualElapsedTime  \
# count  1297627.00  1292881.00  1297627.00  1297627.00         1292044.00
# mean      1467.62     1610.28     1634.28     2183.30             133.26
# ...

# %%
test.describe().round(2)
# Out:
#        Unnamed: 0      Year      Month  DayofMonth  DayOfWeek    DepTime  \
# count   639131.00  639131.0  639131.00   639131.00  639131.00  639131.00
# mean   3343070.96    2008.0       6.11       15.77       3.99    1518.08
# std    2067190.23       0.0       3.48        8.78       2.00     450.50
# min          0.00    2008.0       1.00        1.00       1.00       1.00
# 25%    1518726.00    2008.0       3.00        8.00       2.00    1203.00
# 50%    3244765.00    2008.0       6.00       16.00       4.00    1545.00
# 75%    4973701.00    2008.0       9.00       23.00       6.00    1900.00
# max    7009718.00    2008.0      12.00       31.00       7.00    2400.00
#
#        CRSDepTime    ArrTime  CRSArrTime  FlightNum  ActualElapsedTime  \
# count   639131.00  636767.00   639131.00  639131.00          636327.00
# mean      1467.17    1609.85     1634.11    2186.23             133.39
# std        424.68     547.99      464.42    1946.62              72.10
# ...

# %%
#Podem observar que no hi ha molta diferència entre els valors estadístics entre els dos conjunts.
#La diferència més significativa és en els valors mínims i màxims
#La mitjana, i la desviació estandard tenen valors iguals o molt similars

# %% [markdown]
# ### Ex2: Aplica algun procés de transformació (estandarditzar les dades numèriques, crear columnes dummies, polinomis...)

# %% [markdown]
# ### Ex3: Resumeix les noves columnes generades de manera estadística i gràfica
